# %% [markdown]
# <a href="https://colab.research.google.com/github/brandonmartinez050218-ops/AP005-7/blob/main/Tarea_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #udmy2_dataframes_from_list

# %% [markdown]
# Se importa la librería pandas y se le asigna el alias "pd" para facilitar su uso a lo largo del código

# %%
# Create dataframe from a list

import pandas as pd

# %% [markdown]
# Se crea una lista que contiene los números del 1 al 6

# %%
numbers = [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Se convierte la lista de números en un DataFrame, es decir, en una tabla organizada

# %%
pd.DataFrame(numbers)

# %% [markdown]
# Se define una lista de listas, donde cada sublista agrupa un nombre y una edad

# %%
data = [["Jhon",  23], ["Mary", 18], ["Jhon", 31]]

# %% [markdown]
# Se transforma esa lista de datos en un DataFrame con nombres genéricos para columnas y filas

# %%
pd.DataFrame(data)

# %% [markdown]
# Se construye el DataFrame y se especifican los nombres personalizados para cada columna

# %%
pd.DataFrame(data, columns = ["name", "age"])

# %% [markdown]
# Se genera el DataFrame completo: se asignan nombres a las columnas y también identificadores propios para cada fila

# %%
pd.DataFrame(data, columns = ["name", "age"], index = ["id1", "id2", "id3"])

# %% [markdown]
# #udmy3_dataframe_from_dictionary

# %% [markdown]
# Se importa la librería pandas y se establece el alias "pd" para referirse a ella de forma más breve

# %%
import pandas as pd

# %% [markdown]
# Se crea un diccionario donde cada clave representa una columna, y los valores son los datos de esa columna

# %%
data = {"name": ["Sally", "Jhon", "Kim"], "age": [4, 6 ,7], "gender": ["female", "male", "male"]}

# %% [markdown]
# Se convierte el diccionario en un DataFrame; los nombres de las columnas se toman automáticamente de las claves

# %%
pd.DataFrame(data)

# %% [markdown]
# Se genera el DataFrame y además se asignan identificadores personalizados para nombrar cada fila

# %%
pd.DataFrame(data, index = ["Kid1", "Kid2", "Kid3"])

# %% [markdown]
# #udmy4_dataframefromfile

# %% [markdown]
# Se importa la librería pandas y se carga el contenido del archivo Excel en la tabla denominada "nba", para luego visualizar todo su contenido

# %%
import pandas as pd
nba = pd.read_excel('Nba Teams.xlsx')
nba

# %% [markdown]
# Se ejecuta una función que muestra el resumen general de la tabla: estructura, cantidad de registros, tipos de datos y si hay valores incompletos

# %%
nba.info()

# %% [markdown]
# Se obtienen y se muestran las primeras filas de la tabla, lo que permite revisar de forma rápida cómo están organizados los datos

# %%
nba.head()

# %% [markdown]
# Se seleccionan primero las 5 primeras filas y solo sobre esa parte, se presenta el resumen de información correspondiente a esa selección

# %%
nba.head(5).info()

# %% [markdown]
# #udmy5

# %% [markdown]
# Se importa la librería pandas, se lee el archivo Excel con los datos de los equipos y se visualizan las primeras filas para revisar su contenido
# import pandas as pd

# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %% [markdown]
# Se selecciona y se muestra únicamente la columna llamada "Name", que contiene los nombres correspondientes de cada registro

# %%
nba["Name"]

# %% [markdown]
# Se extrae y se visualiza toda la información de la columna "Salary", donde aparecen los valores relacionados con los sueldos

# %%
nba["Salary"]

# %% [markdown]
# Se accede a la columna "Name" mediante una forma abreviada de escribirlo, obteniendo el mismo resultado que con la notación entre corchetes

# %%
nba.Name

# %% [markdown]
# #udmy6

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel con los datos de los equipos y se muestran las primeras filas para ver la estructura general

# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %% [markdown]
# Se seleccionan y se presentan únicamente las dos columnas indicadas: los nombres y los equipos correspondientes a cada registro

# %%
nba[["Name", "Team"]]

# %% [markdown]
# Se extraen conjuntamente tres columnas, mostrando de forma agrupada el nombre, el equipo y el sueldo de cada registro

# %%
nba[["Name", "Team", "Salary"]]

# %% [markdown]
# #udmy7

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel con los datos y se visualizan las primeras filas para conocer su estructura

# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %% [markdown]
# Se crean dos nuevas columnas en la tabla, ambas se inicializan con espacios vacíos como valor provisional

# %%
nba["Teams"] = " "
nba["nba Teams"] = " "
nba.head()

# %% [markdown]
# Se dejan como comentario varias líneas que no se ejecutan; se prueba acceder a una columna existente y otra que se creó, se muestra la columna Teams y se comenta la referencia a otra columna pendiente

# %%
#nba.Name
#nba.nba Teams
nba.Teams
#nba.Sports

# %% [markdown]
# Se agrega una columna nueva llamada "Sports" y se le asigna el valor fijo "basket" para todos los registros, luego se revisa el resultado con las primeras filas

# %%
nba["Sports"] = "basket"
nba.head()

# %% [markdown]
# Se elimina definitivamente la columna "Teams" de la tabla; las dos líneas siguientes quedan comentadas y no se ejecutan, por lo que no se realiza ninguna inserción de columnas en esta instancia

# %%
nba.drop("Teams", axis = 1, inplace = True)
#nba.insert(2, column = "Teams", value = "Colombians")
#nba.insert(2, column = "Sportss", value = "Turmequé")
nba

# %% [markdown]
# Se visualiza el estado actual de la tabla después de los cambios aplicados

# %%
nba

# %% [markdown]
# Se inserta una columna nueva en la posición número 2, asignándole el nombre "Teams" y el valor "Colombians" para todas las filas

# %%
nba.insert(2, column = "Teams", value = "Colombians")

# %% [markdown]
# Se muestra la tabla completa con la nueva columna ya incorporada

# %%
nba

# %% [markdown]
# #udmy8

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel con los datos y se muestran las primeras filas para ver la estructura inicial

# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %% [markdown]
# Se elimina la columna "Salary" de forma temporal; el resultado se muestra pero no se guarda el cambio en la tabla original

# %%
nba.drop("Salary", axis = 1)

# %% [markdown]
# Se visualiza el contenido actual de la tabla, donde la columna "Salary" sigue apareciendo porque el cambio anterior no se aplicó definitivamente

# %%
nba

# %% [markdown]
# Se elimina la columna "Salary" de forma permanente; el parámetro inplace=True hace que la modificación se guarde directamente en la tabla

# %%
nba.drop("Salary", axis = 1, inplace = True)

# %% [markdown]
# Se muestra la tabla actualizada, ya sin la columna "Salary"

# %%
nba

# %% [markdown]
# Se eliminan conjuntamente las columnas "Team" y "Division", aplicando el cambio de forma permanente en la tabla

# %%
nba.drop(["Team", "Division"], axis = 1, inplace = True)

# %% [markdown]
# Se presenta el estado final de la tabla, donde ya no aparecen las tres columnas eliminadas

# %%
nba

# %% [markdown]
# #udmy9

# %% [markdown]
# Se importa la librería pandas y se carga el archivo Excel desde la ruta indicada; se deja comentada la visualización de las últimas filas y se muestra la tabla completa

# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')
#nba.tail()
nba

# %% [markdown]
# Se importa la herramienta para conectar con Google Drive y se procede a montar y acceder al almacenamiento del drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se presenta el resumen general de la tabla: cantidad de registros, columnas, tipos de datos y si hay valores registrados o no

# %%
nba.info()

# %% [markdown]
# Se revisa cada posición de la tabla y se indica con verdadero o falso si falta algún valor en cada casilla

# %%
nba.isnull()

# %% [markdown]
# Se suman por columna los valores que están vacíos o faltantes, para saber cuántos datos incompletos hay en cada una

# %%
nba.isnull().sum()

# %% [markdown]
# #udmy10

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel desde la ruta especificada y se visualizan las primeras filas para ver la estructura de los datos

# %%
import pandas as pd
nba = pd.read_excel("/content/drive/MyDrive/udmy/AP005320241/Nba Teams.xlsx")
nba.head()

# %% [markdown]
# Se importa la herramienta de conexión con Google Colab y se monta el almacenamiento de Drive para acceder a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se repite la conexión con Google Drive y, una vez establecida, se muestran las primeras 10 filas de la tabla para ampliar la revisión de los datos

# %%
from google.colab import drive
drive.mount('/content/drive')
nba.head(10)

# %% [markdown]
# Se obtienen y se muestran las últimas filas de la tabla, para examinar cómo finaliza el conjunto de datos cargado

# %%
nba.tail()

# %% [markdown]
# Se crea una tabla nueva eliminando todas las filas que contienen algún valor faltante; el resultado se guarda en la variable nbaNoNull y se visualiza

# %%
nbaNoNull = nba.dropna()
nbaNoNull

# %% [markdown]
# Se muestra el estado actual de la tabla original, que conserva todos sus registros incluyendo aquellos con datos faltantes

# %%
nba

# %% [markdown]
# Se deja comentada la opción de borrar filas con valores faltantes de forma permanente; se ejecuta la eliminación sin guardar el cambio y se comprueba que la tabla original se mantiene igual

# %%
#nba.dropna(inplace=True)
nba.dropna()
nba

# %% [markdown]
# Se presenta el resumen detallado de la tabla: cantidad de registros, columnas, tipos de datos y cantidad de valores no nulos en cada una

# %%
nba.info()

# %% [markdown]
# Se visualiza el contenido completo de la tabla en su estado actual

# %%
nba

# %% [markdown]
# Se eliminan únicamente las filas donde todos sus valores están vacíos; el resultado se muestra pero no se modifica la tabla original

# %%
nba.dropna(how="all")

# %% [markdown]
# Se eliminan las filas que contengan al menos un valor faltante; al no especificar guardado, el cambio solo se presenta en pantalla

# %%
nba.dropna(axis = 0)

# %% [markdown]
# Se cambia la dirección de limpieza: se eliminan las columnas completas que tengan algún valor faltante, en lugar de las filas

# %%
nba.dropna(axis=1)

# %% [markdown]
# Se eliminan solamente las filas que presentan valores faltantes en al menos una de las tres columnas indicadas: Name, Salary o College

# %%
nba.dropna(subset = ["Name", "Salary", "College"])

# %% [markdown]
# #udmy11

# %% [markdown]
# Se importa la librería pandas y se carga el archivo Excel con los datos desde la ruta indicada

# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# Se importa la herramienta necesaria y se procede a conectar con el almacenamiento de Google Drive para acceder a los archivos

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se muestran las primeras 10 filas de la tabla para revisar con mayor detalle el contenido de los datos

# %%
nba.head(10)

# %% [markdown]
# Se reemplazan todos los valores faltantes de la tabla por el número 0; el resultado se visualiza pero no se guarda de forma permanente

# %%
nba.fillna(0)

# %% [markdown]
# Se aplica el reemplazo de valores faltantes únicamente en la columna "College", asignándoles el valor 0 y guardando el cambio directamente en la tabla

# %%
nba[["College"]].fillna(0, inplace = True)
nba

# %% [markdown]
# Se sustituyen los valores faltantes de la columna "Name" por el texto "Missing name", aplicando la modificación de forma permanente

# %%
nba["Name"].fillna("Missing name", inplace = True)
nba

# %% [markdown]
# #udmy12

# %% [markdown]
# Se importa la librería pandas y se carga el archivo Excel con los datos desde la ruta especificada

# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para tener acceso a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se selecciona y se muestra únicamente la columna "Salary", donde se encuentran los valores correspondientes a los sueldos

# %%
nba["Salary"]

# %% [markdown]
# Se suma la cantidad de 50000 a cada valor de la columna "Salary"; el resultado se presenta en pantalla sin modificar la tabla original

# %%
nba["Salary"].add(50000)

# %% [markdown]
# Se realiza la misma operación de suma de forma alternativa: se añaden 2000000 a cada sueldo, mostrando el resultado sin guardar cambios

# %%
nba["Salary"] + 2000000

# %% [markdown]
# Se crea una columna nueva llamada "bonus_salary", donde se guarda el resultado de sumar 30000 a cada sueldo; la tabla se actualiza con esta información

# %%
nba["bonus_salary"] = nba["Salary"] + 30000
nba

# %% [markdown]
# Se restan 55000 a cada valor de la columna "Salary"; la línea siguiente se deja comentada y no se ejecuta

# %%
nba["Salary"].sub(55000)
#nba["Salary"] - sub(55000)

# %% [markdown]
# Se divide cada sueldo entre 1000000; la notación alternativa se deja igualmente como comentario sin ejecutarse

# %%
nba["Salary"].div(1000000)
#nba["Salary"]/1000000

# %% [markdown]
# Se multiplican los valores de la columna "Weight" por el factor de conversión a kilogramos; la forma abreviada se mantiene comentada

# %%
nba["Weight"].mul(0.453592)
#nba["Weight"]*0.453592

# %% [markdown]
# #udmy13

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel con los datos desde la ruta indicada y se muestran las primeras filas para revisar su estructura

# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')
nba.head()

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para acceder a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se cuenta cuántas veces aparece cada nombre dentro de la columna "Team", mostrando la cantidad de registros por equipo

# %%
nba["Team"].value_counts()

# %% [markdown]
# Se deja comentada la cuenta de valores de la columna "Division"; se ejecuta en su lugar el recuento de la columna "Division" ordenado de menor a mayor cantidad

# %%
#nba["Division"].value_counts()
nba["Division"].value_counts(ascending = True)

# %% [markdown]
# #udmy14

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel con los datos desde la ruta indicada y se muestran las primeras filas para ver la estructura inicial

# %%
import pandas as pd
nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx")
nba.head()

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para tener acceso a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se ordenan todos los registros alfabéticamente según la columna "Name" y se muestran las primeras 20 filas del resultado

# %%
nba.sort_values("Name").head(20)

# %% [markdown]
# Se ordenan los registros por el valor de la columna "Salary" de forma ascendente; la línea siguiente se deja comentada, por lo que no se aplica orden descendente ni se guarda el cambio

# %%
nba.sort_values("Salary")
#nba.sort_values("Salary", ascending = False, inplace = True)

# %% [markdown]
# Se ordenan los registros primero por equipo y luego por nombre; la opción de colocar los valores faltantes al inicio se deja comentada y no se ejecuta

# %%
nba.sort_values(["Team", "Name"])
#nba.sort_values(["Team", "Name"], na_position = 'first')

# %% [markdown]
# #udmy15

# %% [markdown]
# Se importa la librería pandas, se carga el archivo Excel con los datos; se ordenan los registros por equipo y luego por nombre, colocando los valores faltantes al inicio y guardando el cambio de forma permanente; después se muestra la tabla

# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')
nba.sort_values(["Team", "Name"], na_position = "first", inplace = True)
nba

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para acceder a los archivos

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se reordenan las filas recuperando el orden original según los identificadores de cada registro

# %%
nba.sort_index()

# %% [markdown]
# #udmy16

# %% [markdown]
# Se importa la librería pandas; se deja comentada una ruta alternativa y se carga el archivo desde la ruta de Drive, eliminando de entrada las filas que están completamente vacías, para luego mostrar la tabla resultante

# %%
import pandas as pd
#nba = pd.read_excel("Nba Teams.xlsx")
nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx").dropna(how = "all")
nba

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para acceder a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se presenta el resumen detallado de la tabla: cantidad de registros, columnas, tipos de datos y valores existentes en cada una

# %%
nba.info()

# %% [markdown]
# Se sustituyen los valores faltantes de la columna "Height" por el texto "Missing"; el resultado se muestra sin guardar la modificación en la tabla original

# %%
nba["Height"].fillna("Missing")

# %% [markdown]
# #udmy17

# %%
#Optimizing dataset

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para tener acceso a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se importa la librería pandas y se carga el archivo CSV con los datos de Instagram; se muestran las primeras filas para revisar su estructura

# %%
import pandas as pd
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta.head()

# %% [markdown]
# Se presenta el resumen general de la tabla: cantidad de registros, columnas, tipos de datos y valores existentes en cada una

# %%
insta.info()

# %% [markdown]
# Se vuelve a cargar el mismo archivo CSV desde la ruta indicada y se visualiza el contenido completo de la tabla

# %%
insta = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv")
insta

# %% [markdown]
# Se convierte el contenido de la columna "reg date" al formato de fecha y hora; el cambio se aplica y se muestra la tabla actualizada

# %%
insta["reg date"] = pd.to_datetime(insta["reg date"])
insta

# %% [markdown]
# Se comprueba la estructura de la tabla para verificar que el tipo de dato de la columna modificada ha cambiado correctamente

# %%
insta.info()

# %% [markdown]
# Se transforma la columna "last login" al formato de fecha; se deja comentada la eliminación de esa columna y se muestra el resumen de información

# %%
insta["last login"] = pd.to_datetime(insta["last login"])
#insta.drop("last login", axis = 1, inplace = True)
insta.info()

# %% [markdown]
# Se calcula y se muestra la cantidad de valores distintos que aparecen dentro de la columna "gender"

# %%
insta["gender"].nunique()

# %% [markdown]
# Se vuelve a presentar el resumen detallado de la tabla para consultar su estructura actual

# %%
insta.info()

# %% [markdown]
# Se convierte el contenido de la columna "gender" al tipo de dato categoría, lo que optimiza el almacenamiento cuando hay valores repetidos; el resultado se muestra sin aplicar el cambio

# %%
insta["gender"].astype("category")

# %% [markdown]
# Se reasigna la conversión, de modo que el cambio a tipo categoría se guarda de forma permanente; después se verifica la estructura de la tabla

# %%
insta["gender"] = insta["gender"].astype("category")
insta.info()

# %% [markdown]
# Se selecciona y se muestra únicamente la columna "Country", que contiene los países correspondientes a cada registro

# %%
insta["Country"]

# %% [markdown]
# #udmy18

# %%
#Refine Dataset by a Condition

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para acceder a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se carga el archivo CSV con los datos de Instagram; se convierten las dos columnas de fechas al formato correspondiente, se transforman las columnas de texto a tipo categoría y la columna Influencer a valor lógico, para luego verificar la estructura resultante

# %%
import pandas as pd

insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta["reg date"] = pd.to_datetime(insta["reg date"])
insta["last login"] = pd.to_datetime(insta["last login"])
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta["Influencer"] = insta["Influencer"].astype("bool")
insta.info()

# %% [markdown]
# Se repite la carga del archivo indicando directamente qué columnas son de fecha; se aplican las mismas conversiones de tipo categoría y valor lógico que en el paso anterior

# %%
import pandas as pd

insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta["Influencer"] = insta["Influencer"].astype("bool")

# %% [markdown]
# Se presenta el resumen detallado de la tabla para confirmar que todos los tipos de dato han quedado correctamente establecidos

# %%
insta.info()

# %% [markdown]
# Se muestran las primeras 3 filas de la tabla para revisar de forma rápida el contenido de los registros

# %%
insta.head(3)

# %% [markdown]
# Se filtran y se muestran únicamente los registros donde el género es masculino y, por separado, aquellos que corresponden a Australia

# %%
insta[insta["gender"] == "Male"]
insta[insta["Country"] == "Australia"]

# %% [markdown]
#  Se crea una condición de selección para identificar los registros de género femenino y, a continuación, se muestran solo las filas que cumplen esa condición

# %%
mask = insta["gender"] == "Female"
insta[mask]

# %% [markdown]
# Se seleccionan todos los registros donde la columna Influencer tiene el valor verdadero, es decir, donde se confirma esa condición

# %%
insta[insta["Influencer"] == True]

# %% [markdown]
# Se establece una condición para excluir a los usuarios de Estados Unidos y se muestran únicamente los registros de los demás países

# %%
mask1 = insta["Country"] != "United States"
insta[mask1]

# %% [markdown]
# #udmy19

# %% [markdown]
# Se prepara el entorno de trabajo: se importa la librería pandas, se carga el archivo CSV indicando las columnas de fecha, se convierten las columnas al tipo de dato adecuado y se muestran las primeras filas; se deja comentada una forma alternativa de cargar el archivo

# %%
#Refine Dataframe using Multiple Conditions AND

import pandas as pd

#insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta["Influencer"] = insta["Influencer"].astype("bool")

insta.head()

# %% [markdown]
# Se importa la herramienta de conexión y se monta el almacenamiento de Google Drive para acceder a los archivos guardados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Se combinan tres condiciones al mismo tiempo: se seleccionan los usuarios de género masculino que se registraron a partir de 2016 y que son de Estados Unidos; las filas que cumplen todo se muestran en pantalla

# %%
#Print our Male instagram users that joined since 2016 and they are from USA

mask = (insta["gender"] == "Male") & (insta["reg date"] > "2015-12-31") & (insta["Country"] == "United States")
insta[mask]

# %% [markdown]
# Se desglosan las mismas condiciones en variables separadas y luego se combinan para obtener el mismo resultado que en el fragmento anterior

# %%
mask1 = insta["gender"] == "Male"
mask2 = insta["reg date"] > "2015-12-31"
mask3 = insta["Country"] == "United States"
insta[mask1 & mask2 & mask3]

# %% [markdown]
# Se establece una condición con dos requisitos: género masculino y registro posterior a 2015; al escribir "male" con minúscula puede no coincidir con los valores reales, por lo que el resultado podría aparecer vacío

# %%
mask = (insta["gender"] == "male") & (insta["reg date"] > "2015-12-31")
insta[mask]
